# %% [markdown]
# # Using Google Generative AI to Analyze Images with Questions

# %% [markdown]
# We utilize generative AI for analyzing images using single-shot prompting techniques, where we provide both specific questions and images as input to generate detailed textual responses.

# %%
# !pip install -U google-generativeai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 163.9/163.9 kB 1.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 718.3/718.3 kB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 50.1/50.1 kB 2.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.1/4.1 MB 2.3 MB/s eta 0:00:00
# ...

# %%
import base64
import PIL.Image
import matplotlib.pyplot as plt
import google.generativeai as genai

# %%
def preprocess_image(image_path):
    with open(image_path, 'rb') as img:
        encoded_string = base64.b64encode(img.read())
    return encoded_string.decode('utf-8')

# %%
genai.configure(api_key="AIzaSyBeyO5iC5qMroGr67oa4IgwW5Qo5xzI43o")
model = genai.GenerativeModel('gemini-pro-vision')

# %%
img_path = 'C:/Users/MANOJ/Downloads/wallpapersden.com_australia-model-miranda-kerr_3840x2160.jpg'
img = PIL.Image.open(img_path)

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 3839.5, 2159.5, -0.5)

# %%
text = "who is this model? explain this image."
response = model.generate_content([text,img])
print(response.text)
# Out:
#  This is a photo of model Miranda Kerr. She is wearing a white blazer and a lot of jewelry. She is looking at the camera with a serious expression. The photo is taken from a professional photoshoot.

# %%
img_path = 'C:/Users/MANOJ/Downloads/models2.jpg'
img = PIL.Image.open(img_path)

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 1919.5, 1079.5, -0.5)

# %%
text = "Name the models in the photo"
response = model.generate_content([text,img])
print(response.text)
# Out:
#  The models in the photo are (from left to right): Joan Smalls, Cindy Crawford, Christy Turlington, and Helena Christensen.

# %%
text = "Give more details about the phototshoot?"
response = model.generate_content([text,img])
print(response.text)
# Out:
#  The photoshoot took place in a studio. There are four models sitting on chairs. The models are wearing different clothes. The background is grey. The models are all smiling. The photoshoot was taken by a professional photographer.

# %%
text = "Was the photoshoot specifically taken for any event ?"
response = model.generate_content([text,img])
print(response.text)
# Out:
#  The photoshoot was taken for the December 2022 issue of British Vogue. The issue celebrates the 150th anniversary of the magazine.

# %% [markdown]
# Graphs and Charts

# %%
img_path = 'C:/Users/MANOJ/Downloads/Charts-and-Graphs.jpg'
img = PIL.Image.open(img_path)

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 1771.5, 1771.5, -0.5)

# %%
text = "Explain this image"
response = model.generate_content([text,img])
print(response.text)
# Out:
#  The image shows a pie chart of the regional distribution of a company's customers. The majority of customers are in North America (48.6%), followed by Europe (27.8%), Australasia (16.7%), and the rest of the world (6.9%).

# %% [markdown]
# Mathematical Equations

# %%
img_path = 'C:/Users/MANOJ/Downloads/equations.jfif'
img = PIL.Image.open(img_path)

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 428.5, 219.5, -0.5)

# %%
text = "Explain this image"
response = model.generate_content([text,img])
print(response.text)
# Out:
#  The image shows a quadratic equation, which is an equation that can be written in the form ax^2 + bx + c = 0, where a, b, and c are constants and x is the variable. In this case, the equation is (x + 3)^2 = 4, which means that x^2 + 6x + 9 = 4.

# %%
text = "what is the value of x ?"
response = model.generate_content([text,img])
print(response.text)
# Out:
#  The answer is -1
#
# (x+3)^2 = 4
#
# (x+3) = √4
#
# x+3 = 2
#
# x = -1

# %%
img_path = 'C:/Users/MANOJ/Downloads/Times-Of-India-Newspapers-Dated.jpg'
img = PIL.Image.open(img_path)

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 795.5, 545.5, -0.5)

# %%
text = "What newspaper is this ?"
response = model.generate_content([text,img])
print(response.text)
# Out:
#  The Times of India

# %%
text = "list how many of subtitles are in the paper and list them"
response = model.generate_content([text,img])
print(response.text)
# Out:
#  There are 5 subtitles in the paper. They are:
# 1. 13 bogies of Kalka Mail go off the rails, 35 killed
# 2. Train Speeding At 108kmph: Sabotage
# 3. Explosion on Assam tracks injures 100
# 4. Study trashes claim of 5% rise in forest cover
# 5. Three killed in police firing in Mayurbhanj

# %% [markdown]
# Translations

# %%
img_path = 'C:/Users/MANOJ/Downloads/imghindi.jpg'
img = PIL.Image.open(img_path)

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 735.5, 653.5, -0.5)

# %%
text = "Whats language is this ? "
response = model.generate_content([text,img])
print(response.text)
# Out:
#  This is Hindi.

# %%
text = "Translate this in english ? "
response = model.generate_content([text,img])
print(response.text)
# Out:
#  If you have to write, write in short, Because the mind also gets tired...
